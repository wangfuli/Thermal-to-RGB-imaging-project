# %% [markdown]
# # Thermal camera project overview
#
# ---
#
#
# What we're going to do in this project?
#
#
# *   Read collected images into python
# *   Create preprocessing function for our data
# *   Build neural network model
# *   Feed data into the model and start training
# *   Compare traning results and the groudtruth

# %%
# import python libraries
import cv2
import os
import numpy as np
from PIL import Image

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# check current working directory, make sure the data is stored in the directory
os.getcwd()
# Out:
# '/content'

# %%
# change working directory to the data folder
os.chdir('/content/drive/MyDrive/Digital imaging project/Thermal/data')

# %%
# define the image loading function and resize all images to the same size
def load_images_from_folder(folder, target_size = (256, 256)):
    images = []
    for filename in os.listdir(folder):
      
      if folder == "Thermal Buildings":
        img = cv2.imread(os.path.join(folder,filename), 3)
        b,g,r = cv2.split(img)       # get b, g, r, cv2 uses bgr so we need to switch it to rgb
        img = cv2.merge([r,g,b])     # switch it to r, g, b
        img = np.array(img)
  
      if folder == "RGB Buildings":
          img = cv2.imread(os.path.join(folder,filename), 0)
          #zoom in image
          new_rgb = np.zeros((340, 440), dtype=np.uint8)
          for i in range(40, img.shape[0]-100):
            for j in range(110, img.shape[1]-90):
              new_rgb[i-40, j-110] = img[i, j]
          new_rgb = cv2.resize(new_rgb, (640, 480), cv2.INTER_CUBIC) #notice that cv2.resize uses reversed order of image shape
          img = np.array(new_rgb, dtype='uint8')

        #reshape to target size
      h, w = img.shape[:2]
      c = img.shape[2] if len(img.shape) > 2 else 1
      if h == w:
          return cv2.resize(img, target_size, cv2.INTER_AREA)
      
      dif = h if h > w else w

      interpolation = cv2.INTER_AREA if dif > (target_size[0]+target_size[1])//2 else cv2.INTER_CUBIC

      x_pos = (dif - w)//2
      y_pos = (dif - h)//2

      if len(img.shape) == 2:
          mask = np.zeros((dif, dif), dtype=img.dtype)
          mask[y_pos:y_pos+h, x_pos:x_pos+w] = img[:h, :w]
      else:
          mask = np.zeros((dif, dif, c), dtype=img.dtype)
          mask[y_pos:y_pos+h, x_pos:x_pos+w, :] = img[:h, :w, :]

      img1 = Image.open(os.path.join(folder,filename))
      new1 = cv2.resize(mask, target_size, interpolation)
      new1 = np.array(new1, dtype='uint8') 
      images.append(new1)
    return images

# %%
#load the two groups of images
thermal = load_images_from_folder("Thermal Buildings")

# %%
gt = load_images_from_folder("RGB Buildings")

# %%
#check if images are in the desired size
thermal[0].shape   #the first image
# Out:
# (256, 256, 3)

# %%
gt[0].shape
# Out:
# (256, 256)

# %%
print(len(thermal))
print(len(gt))
# Out:
# 1263
# 1263

# %% [markdown]
# # Step 2: Data pre-processing
# * Split the dataset into training and testing sets
# - (The function train_test_split can do it automatically for us, the argument test_size means the proportion of testing set,
# which is generally set as 0.2, and the random_state is the seed to ramdomly select testing images. We set the random_state because we want to reproduce the same data split everytime we run the code.)

# %% [markdown]
# #Create rotated images

# %%
import imutils

# %%
def Rotate(imgs, degree):
  """Take a list of images, rotate each of them by the degree 
  counterclockwise and output rotated images."""
  rotated_imgs = []
  for img in imgs:
    rotated_img = imutils.rotate(img, angle=degree)
    rotated_imgs.append(rotated_img)
  return rotated_imgs

# %%
rotated_thermal = Rotate(thermal, 90)
rotated_gt = Rotate(gt, 90)

# %%
#plot images and rotated images
import matplotlib.pyplot as plt
f, ax = plt.subplots(2,2)
ax[0,0].imshow(thermal[0])
ax[0,1].imshow(rotated_thermal[0])
ax[1,0].imshow(gt[0], cmap='gray')
ax[1,1].imshow(rotated_gt[0], cmap='gray')

# %% [markdown]
# After rotation, we will have double amount of images, so that we need to group all thermal images and all RGB images toghter

# %%
thermal_all = thermal + rotated_thermal
gt_all = gt + rotated_gt

# %%
print(len(thermal_all)) #notice the number of images are doubled
print(len(gt_all))
# Out:
# 2526
# 2526

# %%
from sklearn.model_selection import train_test_split

# %%
#use the below for the full data size, but the other one is for quicker testing
thermal_train, thermal_test, gt_train, gt_test = train_test_split(thermal_all, gt_all, test_size=0.2, random_state=42)
#thermal_train, thermal_test, gt_train, gt_test = train_test_split(thermal[0:100], gt[0:100], test_size=0.2, random_state=42)
print(f'There are {len(thermal_all)} thermal images and {len(gt_all)} RBG images.')  #these two number should be the same
print(f'The training set contains {len(thermal_train)} images, and the testing set contains {len(thermal_test)} images.') # the sum should add up to len(thermal)
# Out:
# There are 2526 thermal images and 2526 RBG images.
# The training set contains 2020 images, and the testing set contains 506 images.

# %% [markdown]
# # Step 3: Build convolutional neural network from the tensorflow library

# %%
import tensorflow as tf
import keras
from keras.models import Sequential, load_model
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D, UpSampling2D, Conv2DTranspose

# %%
# the input shape of neural network should be the same as the image size
in_shape = thermal[0].shape
print(in_shape)
# Out:
# (256, 256, 3)

# %%
encoder = Sequential()
encoder.add(Conv2D(32, 3, strides=1, padding='same', activation='relu', input_shape=(256, 256, 3)))
encoder.add(MaxPooling2D(2, strides=2))
encoder.add(Conv2D(64, 3, strides=1, padding='same', activation='relu'))
encoder.add(MaxPooling2D(2, strides=2))
encoder.add(Conv2D(128, 3, strides=1, padding='same', activation='relu'))
encoder.add(MaxPooling2D(2, strides=2))
encoder.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 256, 256, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 128, 128, 32)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 128, 128, 64)      18496
#
#  max_pooling2d_1 (MaxPooling  (None, 64, 64, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 64, 64, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 32, 32, 128)      0
#  2D)
#
# =================================================================
# Total params: 93,248
# Trainable params: 93,248
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.backend import conv2d_transpose
decoder = Sequential()
decoder.add(Conv2DTranspose(128, 3, strides=2, padding='same', activation='relu', input_shape=encoder.output.shape[1:]))
decoder.add(Conv2DTranspose(16, 3, strides=2, padding='same', activation='relu'))
decoder.add(Conv2DTranspose(1, 3, strides=2, padding='same', activation='relu'))
decoder.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_transpose (Conv2DTra  (None, 64, 64, 128)      147584
#  nspose)
#
#  conv2d_transpose_1 (Conv2DT  (None, 128, 128, 16)     18448
#  ranspose)
#
#  conv2d_transpose_2 (Conv2DT  (None, 256, 256, 1)      145
#  ranspose)
#
# =================================================================
# Total params: 166,177
# Trainable params: 166,177
# Non-trainable params: 0
# _________________________________________________________________

# %%
conv_autoencoder = keras.Model(inputs=encoder.input, outputs=decoder(encoder.outputs))

# %%
class CustomLoss(tf.keras.losses.Loss):
  def __init__(self):
    super().__init__()
  def call(self, im1, im2):
    #convert images to the format of tf.image.ssim
    y_true = tf.expand_dims(im1, axis=-1)

    y_true = tf.image.convert_image_dtype(y_true, tf.float32)
    y_pred = tf.image.convert_image_dtype(im2, tf.float32)
    # print(y_true.shape)
    # print(y_pred.shape)
    #loss_mse = tf.keras.losses.MSE

    return 1 - tf.reduce_mean(tf.image.ssim(y_true, y_pred, 1.0)) # minimize mse and maximize ssim

# %%
# specify the loss function we are using to train the model
# mse = tf.keras.losses.MeanSquaredError()
# cross_entropy = tf.keras.losses.BinaryCrossentropy(from_logits=True)
# compile the model
conv_autoencoder.compile(optimizer="adam", loss=[CustomLoss()])

# %% [markdown]
# # Step 4: Training model

# %% [markdown]
# * Convert the data into tensorflow-compatible format
# * The data is originally a list of images with size (256, 256, 3), but we want a numpy array of shape (length, 256, 256, 3)
# * In order to do this, we stack images along the first dimension

# %%
# convert training data
gt_train_ = np.stack(gt_train)
thermal_train_ = np.stack(thermal_train)
print(gt_train_.shape, thermal_train_.shape)
# Out:
# (2020, 256, 256) (2020, 256, 256, 3)

# %%
# convert testing data
gt_test_ = np.stack(gt_test)
thermal_test_ = np.stack(thermal_test)
print(gt_test_.shape, thermal_test_.shape)
# Out:
# (506, 256, 256) (506, 256, 256, 3)

# %%
# change the scale of pixel to [0, 1]
gt_train_ = gt_train_ / 255.0
thermal_train_ = thermal_train_ / 255.0
gt_test_ = gt_test_ / 255.0
thermal_test = thermal_test_ / 255.0

# %%
from keras.callbacks import ModelCheckpoint #the function used to track trainiing process

# %%
#create callback to track traning
filepath = 'colorTgrayRGB2.hdf5'
checkpoint = ModelCheckpoint(filepath=filepath, 
                             monitor='val_loss',
                             verbose=1, 
                             save_best_only=True,
                             mode='min')
callbacks = [checkpoint]

# %%
history = conv_autoencoder.fit(thermal_train_, gt_train_, batch_size=10, epochs=50, 
validation_data=(thermal_test_, gt_test_), callbacks=callbacks)  #play with batch size and epochs
# Out:
# Epoch 1/50
# 201/202 [============================>.] - ETA: 0s - loss: 0.6527
# Epoch 1: val_loss improved from inf to 0.85618, saving model to colorTgrayRGB2.hdf5
# 202/202 [==============================] - 22s 53ms/step - loss: 0.6522 - val_loss: 0.8562
# Epoch 2/50
# 201/202 [============================>.] - ETA: 0s - loss: 0.5506
# Epoch 2: val_loss did not improve from 0.85618
# 202/202 [==============================] - 9s 45ms/step - loss: 0.5506 - val_loss: 0.8802
# Epoch 3/50
# 201/202 [============================>.] - ETA: 0s - loss: 0.5488
# Epoch 3: val_loss did not improve from 0.85618
# 202/202 [==============================] - 9s 45ms/step - loss: 0.5487 - val_loss: 0.8794
# Epoch 4/50
# 201/202 [============================>.] - ETA: 0s - loss: 0.5480
# Epoch 4: val_loss did not improve from 0.85618
# 202/202 [==============================] - 9s 47ms/step - loss: 0.5481 - val_loss: 0.8782
# Epoch 5/50
# 201/202 [============================>.] - ETA: 0s - loss: 0.5477
# Epoch 5: val_loss did not improve from 0.85618
# 202/202 [==============================] - 9s 45ms/step - loss: 0.5478 - val_loss: 0.8773
# Epoch 6/50
# 201/202 [============================>.] - ETA: 0s - loss: 0.5475
# Epoch 6: val_loss did not improve from 0.85618
# 202/202 [==============================] - 9s 47ms/step - loss: 0.5477 - val_loss: 0.8728
# Epoch 7/50
# 201/202 [============================>.] - ETA: 0s - loss: 0.5477
# Epoch 7: val_loss did not improve from 0.85618
# 202/202 [==============================] - 9s 45ms/step - loss: 0.5476 - val_loss: 0.8749
# Epoch 8/50
# 201/202 [============================>.] - ETA: 0s - loss: 0.5472
# Epoch 8: val_loss did not improve from 0.85618
# 202/202 [==============================] - 9s 45ms/step - loss: 0.5473 - val_loss: 0.8752
# Epoch 9/50
# 202/202 [==============================] - ETA: 0s - loss: 0.5471
# Epoch 9: val_loss did not improve from 0.85618
# 202/202 [==============================] - 10s 47ms/step - loss: 0.5471 - val_loss: 0.8709
# Epoch 10/50
# 201/202 [============================>.] - ETA: 0s - loss: 0.5470
# Epoch 10: val_loss did not improve from 0.85618
# 202/202 [==============================] - 9s 47ms/step - loss: 0.5470 - val_loss: 0.8716
# Epoch 11/50
# 202/202 [==============================] - ETA: 0s - loss: 0.5472
# Epoch 11: val_loss improved from 0.85618 to 0.82995, saving model to colorTgrayRGB2.hdf5
# 202/202 [==============================] - 10s 49ms/step - loss: 0.5472 - val_loss: 0.8299
# Epoch 12/50
# 201/202 [============================>.] - ETA: 0s - loss: 0.5469
# Epoch 12: val_loss did not improve from 0.82995
# 202/202 [==============================] - 9s 45ms/step - loss: 0.5470 - val_loss: 0.8520
# Epoch 13/50
# 202/202 [==============================] - ETA: 0s - loss: 0.5470
# Epoch 13: val_loss did not improve from 0.82995
# 202/202 [==============================] - 9s 45ms/step - loss: 0.5470 - val_loss: 0.8382
# Epoch 14/50
# 201/202 [============================>.] - ETA: 0s - loss: 0.5469
# Epoch 14: val_loss did not improve from 0.82995
# 202/202 [==============================] - 9s 45ms/step - loss: 0.5470 - val_loss: 0.8508
# Epoch 15/50
# 201/202 [============================>.] - ETA: 0s - loss: 0.5470
# Epoch 15: val_loss did not improve from 0.82995
# 202/202 [==============================] - 10s 47ms/step - loss: 0.5466 - val_loss: 0.8563
# Epoch 16/50
# 201/202 [============================>.] - ETA: 0s - loss: 0.5469
# Epoch 16: val_loss did not improve from 0.82995
# 202/202 [==============================] - 10s 48ms/step - loss: 0.5467 - val_loss: 0.8317
# Epoch 17/50
# 201/202 [============================>.] - ETA: 0s - loss: 0.5468
# Epoch 17: val_loss did not improve from 0.82995
# 202/202 [==============================] - 9s 46ms/step - loss: 0.5466 - val_loss: 0.8546
# Epoch 18/50
# 201/202 [============================>.] - ETA: 0s - loss: 0.5464
# Epoch 18: val_loss did not improve from 0.82995
# 202/202 [==============================] - 9s 46ms/step - loss: 0.5465 - val_loss: 0.8673
# Epoch 19/50
# 201/202 [============================>.] - ETA: 0s - loss: 0.5464
# Epoch 19: val_loss did not improve from 0.82995
# 202/202 [==============================] - 9s 45ms/step - loss: 0.5464 - val_loss: 0.8431
# Epoch 20/50
# 202/202 [==============================] - ETA: 0s - loss: 0.5464
# Epoch 20: val_loss did not improve from 0.82995
# 202/202 [==============================] - 9s 46ms/step - loss: 0.5464 - val_loss: 0.8340
# Epoch 21/50
# 201/202 [============================>.] - ETA: 0s - loss: 0.5462
# Epoch 21: val_loss did not improve from 0.82995
# 202/202 [==============================] - 9s 46ms/step - loss: 0.5462 - val_loss: 0.8399
# Epoch 22/50
# 201/202 [============================>.] - ETA: 0s - loss: 0.5462
# Epoch 22: val_loss did not improve from 0.82995
# 202/202 [==============================] - 9s 46ms/step - loss: 0.5462 - val_loss: 0.8383
# Epoch 23/50
# 201/202 [============================>.] - ETA: 0s - loss: 0.5461
# Epoch 23: val_loss did not improve from 0.82995
# 202/202 [==============================] - 10s 48ms/step - loss: 0.5462 - val_loss: 0.8428
# Epoch 24/50
# 202/202 [==============================] - ETA: 0s - loss: 0.5461
# Epoch 24: val_loss did not improve from 0.82995
# 202/202 [==============================] - 9s 46ms/step - loss: 0.5461 - val_loss: 0.8393
# Epoch 25/50
# 201/202 [============================>.] - ETA: 0s - loss: 0.5460
# Epoch 25: val_loss did not improve from 0.82995
# 202/202 [==============================] - 9s 46ms/step - loss: 0.5461 - val_loss: 0.8505
# Epoch 26/50
# 201/202 [============================>.] - ETA: 0s - loss: 0.5457
# Epoch 26: val_loss did not improve from 0.82995
# 202/202 [==============================] - 9s 46ms/step - loss: 0.5460 - val_loss: 0.8575
# Epoch 27/50
# 201/202 [============================>.] - ETA: 0s - loss: 0.5465
# Epoch 27: val_loss did not improve from 0.82995
# 202/202 [==============================] - 9s 46ms/step - loss: 0.5465 - val_loss: 0.8631
# Epoch 28/50
# 201/202 [============================>.] - ETA: 0s - loss: 0.5462
# Epoch 28: val_loss did not improve from 0.82995
# 202/202 [==============================] - 10s 48ms/step - loss: 0.5463 - val_loss: 0.8414
# Epoch 29/50
# 201/202 [============================>.] - ETA: 0s - loss: 0.5463
# Epoch 29: val_loss did not improve from 0.82995
# 202/202 [==============================] - 10s 48ms/step - loss: 0.5461 - val_loss: 0.8436
# Epoch 30/50
# 201/202 [============================>.] - ETA: 0s - loss: 0.5458
# Epoch 30: val_loss did not improve from 0.82995
# 202/202 [==============================] - 9s 46ms/step - loss: 0.5458 - val_loss: 0.8416
# Epoch 31/50
# 201/202 [============================>.] - ETA: 0s - loss: 0.5458
# Epoch 31: val_loss did not improve from 0.82995
# 202/202 [==============================] - 9s 46ms/step - loss: 0.5458 - val_loss: 0.8387
# Epoch 32/50
# 201/202 [============================>.] - ETA: 0s - loss: 0.5459
# Epoch 32: val_loss did not improve from 0.82995
# 202/202 [==============================] - 9s 46ms/step - loss: 0.5457 - val_loss: 0.8451
# Epoch 33/50
# 202/202 [==============================] - ETA: 0s - loss: 0.5455
# Epoch 33: val_loss did not improve from 0.82995
# 202/202 [==============================] - 10s 48ms/step - loss: 0.5455 - val_loss: 0.8505
# Epoch 34/50
# 202/202 [==============================] - ETA: 0s - loss: 0.5454
# Epoch 34: val_loss did not improve from 0.82995
# 202/202 [==============================] - 9s 46ms/step - loss: 0.5454 - val_loss: 0.8421
# Epoch 35/50
# 201/202 [============================>.] - ETA: 0s - loss: 0.5454
# Epoch 35: val_loss did not improve from 0.82995
# 202/202 [==============================] - 9s 46ms/step - loss: 0.5453 - val_loss: 0.8549
# Epoch 36/50
# 201/202 [============================>.] - ETA: 0s - loss: 0.5453
# Epoch 36: val_loss did not improve from 0.82995
# 202/202 [==============================] - 9s 46ms/step - loss: 0.5453 - val_loss: 0.8591
# Epoch 37/50
# 201/202 [============================>.] - ETA: 0s - loss: 0.5453
# Epoch 37: val_loss did not improve from 0.82995
# 202/202 [==============================] - 9s 46ms/step - loss: 0.5453 - val_loss: 0.8507
# Epoch 38/50
# 201/202 [============================>.] - ETA: 0s - loss: 0.5452
# Epoch 38: val_loss did not improve from 0.82995
# 202/202 [==============================] - 9s 46ms/step - loss: 0.5453 - val_loss: 0.8458
# Epoch 39/50
# 202/202 [==============================] - ETA: 0s - loss: 0.5451
# Epoch 39: val_loss did not improve from 0.82995
# 202/202 [==============================] - 10s 48ms/step - loss: 0.5451 - val_loss: 0.8603
# Epoch 40/50
# 201/202 [============================>.] - ETA: 0s - loss: 0.5451
# Epoch 40: val_loss did not improve from 0.82995
# 202/202 [==============================] - 9s 46ms/step - loss: 0.5451 - val_loss: 0.8457
# Epoch 41/50
# 201/202 [============================>.] - ETA: 0s - loss: 0.5450
# Epoch 41: val_loss did not improve from 0.82995
# 202/202 [==============================] - 10s 48ms/step - loss: 0.5450 - val_loss: 0.8476
# Epoch 42/50
# 201/202 [============================>.] - ETA: 0s - loss: 0.5447
# Epoch 42: val_loss did not improve from 0.82995
# 202/202 [==============================] - 9s 46ms/step - loss: 0.5449 - val_loss: 0.8537
# Epoch 43/50
# 202/202 [==============================] - ETA: 0s - loss: 0.5448
# Epoch 43: val_loss did not improve from 0.82995
# 202/202 [==============================] - 9s 46ms/step - loss: 0.5448 - val_loss: 0.8555
# Epoch 44/50
# 201/202 [============================>.] - ETA: 0s - loss: 0.5452
# Epoch 44: val_loss did not improve from 0.82995
# 202/202 [==============================] - 10s 48ms/step - loss: 0.5449 - val_loss: 0.8718
# Epoch 45/50
# 201/202 [============================>.] - ETA: 0s - loss: 0.5446
# Epoch 45: val_loss did not improve from 0.82995
# 202/202 [==============================] - 10s 48ms/step - loss: 0.5447 - val_loss: 0.8597
# Epoch 46/50
# 201/202 [============================>.] - ETA: 0s - loss: 0.5445
# Epoch 46: val_loss did not improve from 0.82995
# 202/202 [==============================] - 10s 48ms/step - loss: 0.5446 - val_loss: 0.8486
# Epoch 47/50
# 201/202 [============================>.] - ETA: 0s - loss: 0.5444
# Epoch 47: val_loss did not improve from 0.82995
# 202/202 [==============================] - 9s 46ms/step - loss: 0.5446 - val_loss: 0.8576
# Epoch 48/50
# 201/202 [============================>.] - ETA: 0s - loss: 0.5443
# Epoch 48: val_loss did not improve from 0.82995
# 202/202 [==============================] - 9s 46ms/step - loss: 0.5444 - val_loss: 0.8479
# Epoch 49/50
# 202/202 [==============================] - ETA: 0s - loss: 0.5443
# Epoch 49: val_loss did not improve from 0.82995
# 202/202 [==============================] - 10s 48ms/step - loss: 0.5443 - val_loss: 0.8538
# Epoch 50/50
# 201/202 [============================>.] - ETA: 0s - loss: 0.5444
# Epoch 50: val_loss did not improve from 0.82995
# 202/202 [==============================] - 9s 46ms/step - loss: 0.5444 - val_loss: 0.8436

# %% [markdown]
# * Plot the training process
# * if the best model occurs in the middle of epochs, it is overfitting, otherwise, more traning epochs are needed.

# %%
plt.figure(figsize=(8, 8))
plt.title("Optimization curve(Epochs vs Log-loss)")
plt.plot(history.history["loss"], label="loss")
plt.plot(history.history["val_loss"], label="val_loss")
plt.plot(np.argmin(history.history["val_loss"]), np.min(history.history["val_loss"]), marker="x", color="r", label="best model")
plt.xlabel("Epochs")
plt.ylabel("log_loss")
plt.legend()

# %% [markdown]
# # Step 5: Load the best model and use it to predict RGB images, compared with actral RGB images (ground truth)

# %%
#Load the best model version
model = load_model(filepath, compile=False)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_input (InputLayer)   [(None, 256, 256, 3)]     0
#
#  conv2d (Conv2D)             (None, 256, 256, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 128, 128, 32)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 128, 128, 64)      18496
#
#  max_pooling2d_1 (MaxPooling  (None, 64, 64, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 64, 64, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 32, 32, 128)      0
#  2D)
#
#  sequential_1 (Sequential)   (None, 256, 256, 1)       166177
#
# =================================================================
# Total params: 259,425
# Trainable params: 259,425
# Non-trainable params: 0
# _________________________________________________________________

# %%
RGB_predicted = model.predict(thermal_test_).reshape(gt_test_.shape)
#print('Model MSE on test data = ', keras.losses.MeanSquaredError(gt_test_, RGB_predicted).numpy())

# %%
plt.imshow(thermal_train_[52])

# %%
plt.imshow(RGB_predicted[52], cmap='gray')

# %%
plt.imshow(gt_train_[52], cmap='gray')

# %%
def plotImages(images_arr):
  fig,axes = plt.subplots(1,10,figsize=(20,20))
  axes=axes.flatten()
  for img,ax in zip(images_arr,axes):
    #img=img.astype(np.uint)
    ax.imshow(img, cmap='gray')
    ax.axis('off')
  plt.tight_layout()
  plt.show()

# %%
plotImages(RGB_predicted[10:20])
plotImages(thermal_test_[10:20])
plotImages(gt_test_[10:20])
