# %% [markdown]
# # Thermal camera project overview
#
# ---
#
#
# What we're going to do in this project?
#
#
# *   Read collected images into python
# *   Create preprocessing function for our data
# *   Build neural network model
# *   Feed data into the model and start training
# *   Compare traning results and the groudtruth

# %% [markdown]
# # Step 1: Data loading

# %%
# import python libraries
import cv2
import os
import numpy as np
from PIL import Image

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# check current working directory, make sure the data is stored in the directory
os.getcwd()
# Out:
# '/content/drive/.shortcut-targets-by-id/10ka7G--xYdG6spAfyX54VALZMhUm-eec/Digital imaging project/Thermal/data'

# %%
# change working directory to the data folder
os.chdir('/content/drive/MyDrive/Digital imaging project/Thermal/data')

# %%
# define the image loading function and resize all images to the same size
def load_images_from_folder(folder, target_size = (256, 256)):
    images = []
    for filename in os.listdir(folder):
        img = cv2.imread(os.path.join(folder,filename), 3)
        b,g,r = cv2.split(img)           # get b, g, r, cv2 uses bgr so we need to switch it to rgb
        img = cv2.merge([r,g,b])     # switch it to r, g, b
        img = np.array(img)
  
        if folder == "RGB":
            #zoom in image
            new_rgb = np.zeros((340, 440, 3), dtype=np.uint8)
            for i in range(40, img.shape[0]-100):
              for j in range(110, img.shape[1]-90):
                new_rgb[i-40, j-110, :] = img[i, j, :]
            new_rgb = cv2.resize(new_rgb, (640, 480), cv2.INTER_CUBIC) #notice that cv2.resize uses reversed order of image shape
            img = np.array(new_rgb, dtype='uint8')

        #reshape to target size
        h, w = img.shape[:2]
        c = img.shape[2] if len(img.shape) > 2 else 1
        if h == w:
            return cv2.resize(img, target_size, cv2.INTER_AREA)
        
        dif = h if h > w else w

        interpolation = cv2.INTER_AREA if dif > (target_size[0]+target_size[1])//2 else cv2.INTER_CUBIC

        x_pos = (dif - w)//2
        y_pos = (dif - h)//2

        if len(img.shape) == 2:
            mask = np.zeros((dif, dif), dtype=img.dtype)
            mask[y_pos:y_pos+h, x_pos:x_pos+w] = img[:h, :w]
        else:
            mask = np.zeros((dif, dif, c), dtype=img.dtype)
            mask[y_pos:y_pos+h, x_pos:x_pos+w, :] = img[:h, :w, :]

        img1 = Image.open(os.path.join(folder,filename))
        new1 = cv2.resize(mask, target_size, interpolation)
        new1 = np.array(new1, dtype='uint8')
        images.append(new1)
    return images

# %%
#load the two groups of images
thermal = load_images_from_folder("Thermal")

# %%
gt = load_images_from_folder("RGB")

# %%
#check if images are in the desired size
thermal[0].shape   #the first image
# Out:
# (256, 256, 3)

# %%
gt[0].shape
# Out:
# (256, 256, 3)

# %% [markdown]
# # Step 2: Data pre-processing
# * Split the dataset into training and testing sets
# - (The function train_test_split can do it automatically for us, the argument test_size means the proportion of testing set,
# which is generally set as 0.2, and the random_state is the seed to ramdomly select testing images. We set the random_state because we want to reproduce the same data split everytime we run the code.)

# %% [markdown]
# #Create rotated images

# %%
import imutils

# %%
def Rotate(imgs, degree):
  """Take a list of images, rotate each of them by the degree 
  counterclockwise and output rotated images."""
  rotated_imgs = []
  for img in imgs:
    rotated_img = imutils.rotate(img, angle=degree)
    rotated_imgs.append(rotated_img)
  return rotated_imgs

# %%
rotated_thermal = Rotate(thermal, 90)
rotated_gt = Rotate(gt, 90)

# %%
#plot images and rotated images
import matplotlib.pyplot as plt
f, ax = plt.subplots(2,2)
ax[0,0].imshow(thermal[0])
ax[0,1].imshow(rotated_thermal[0])
ax[1,0].imshow(gt[0])
ax[1,1].imshow(rotated_gt[0])

# %% [markdown]
# After rotation, we will have double amount of images, so that we need to group all thermal images and all RGB images toghter

# %%
thermal_all = thermal + rotated_thermal
gt_all = gt + rotated_gt

# %%
print(len(thermal_all)) #notice the number of images are doubled
print(len(gt_all))
# Out:
# 1814
# 1814

# %%
from sklearn.model_selection import train_test_split

# %%
#use the below for the full data size, but the other one is for quicker testing
thermal_train, thermal_test, gt_train, gt_test = train_test_split(thermal_all, gt_all, test_size=0.2, random_state=42)
#thermal_train, thermal_test, gt_train, gt_test = train_test_split(thermal[0:100], gt[0:100], test_size=0.2, random_state=42)
print(f'There are {len(thermal_all)} thermal images and {len(gt_all)} RBG images.')  #these two number should be the same
print(f'The training set contains {len(thermal_train)} images, and the testing set contains {len(thermal_test)} images.') # the sum should add up to len(thermal)
# Out:
# There are 1814 thermal images and 1814 RBG images.
# The training set contains 1451 images, and the testing set contains 363 images.

# %% [markdown]
# # Step 3: Build convolutional neural network from the tensorflow library

# %%
import tensorflow as tf
import keras
from keras.models import Sequential, load_model
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D, UpSampling2D, Conv2DTranspose

# %%
# the input shape of neural network should be the same as the image size
in_shape = thermal[0].shape
print(in_shape)
# Out:
# (256, 256, 3)

# %%
encoder = Sequential()
encoder.add(Conv2D(32, 3, strides=1, padding='same', activation='relu', input_shape=in_shape))
encoder.add(MaxPooling2D(2, strides=2))
encoder.add(Conv2D(64, 3, strides=1, padding='same', activation='relu'))
encoder.add(MaxPooling2D(2, strides=2))
encoder.add(Conv2D(128, 3, strides=1, padding='same', activation='relu'))
encoder.add(MaxPooling2D(2, strides=2))
encoder.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_3 (Conv2D)           (None, 256, 256, 32)      896
#
#  max_pooling2d_3 (MaxPooling  (None, 128, 128, 32)     0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 128, 128, 64)      18496
#
#  max_pooling2d_4 (MaxPooling  (None, 64, 64, 64)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 64, 64, 128)       73856
#
#  max_pooling2d_5 (MaxPooling  (None, 32, 32, 128)      0
#  2D)
#
# =================================================================
# Total params: 93,248
# Trainable params: 93,248
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.backend import conv2d_transpose
decoder = Sequential()
decoder.add(Conv2DTranspose(128, 3, strides=2, padding='same', activation='relu', input_shape=encoder.output.shape[1:]))
decoder.add(Conv2DTranspose(16, 3, strides=2, padding='same', activation='relu'))
decoder.add(Conv2DTranspose(3, 3, strides=2, padding='same', activation='relu'))
decoder.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_transpose_3 (Conv2DT  (None, 64, 64, 128)      147584
#  ranspose)
#
#  conv2d_transpose_4 (Conv2DT  (None, 128, 128, 16)     18448
#  ranspose)
#
#  conv2d_transpose_5 (Conv2DT  (None, 256, 256, 3)      435
#  ranspose)
#
# =================================================================
# Total params: 166,467
# Trainable params: 166,467
# Non-trainable params: 0
# _________________________________________________________________

# %%
conv_autoencoder = keras.Model(inputs=encoder.input, outputs=decoder(encoder.outputs))

# %%
# specify the loss function we are using to train the model
loss_fn = tf.keras.losses.MeanSquaredError()
# compile the model
conv_autoencoder.compile(optimizer='adam', loss=loss_fn)

# %% [markdown]
# # Step 4: Training model

# %% [markdown]
# * Convert the data into tensorflow-compatible format
# * The data is originally a list of images with size (256, 256, 3), but we want a numpy array of shape (length, 256, 256, 3)
# * In order to do this, we stack images along the first dimension

# %%
# convert training data
gt_train_ = np.stack(gt_train)
thermal_train_ = np.stack(thermal_train)
print(gt_train_.shape, thermal_train_.shape)
# Out:
# (1451, 256, 256, 3) (1451, 256, 256, 3)

# %%
# convert testing data
gt_test_ = np.stack(gt_test)
thermal_test_ = np.stack(thermal_test)
print(gt_test_.shape, thermal_test_.shape)
# Out:
# (363, 256, 256, 3) (363, 256, 256, 3)

# %%
from keras.callbacks import ModelCheckpoint #the function used to track trainiing process

# %%
#create callback to track traning
filepath = 'best_everything_model.hdf5'
checkpoint = ModelCheckpoint(filepath=filepath, 
                             monitor='val_loss',
                             verbose=1, 
                             save_best_only=True,
                             mode='min')
callbacks = [checkpoint]

# %%
history = conv_autoencoder.fit(thermal_train_, gt_train_, batch_size=5, epochs=250, 
validation_data=(thermal_test_, gt_test_), callbacks=callbacks)  #play with batch size and epochs
# Out:
# Epoch 1/100
# 484/484 [==============================] - ETA: 0s - loss: 4241.0234
# Epoch 1: val_loss improved from inf to 3804.22900, saving model to my_best_model.hdf5
# 484/484 [==============================] - 147s 303ms/step - loss: 4241.0234 - val_loss: 3804.2290
# Epoch 2/100
# 484/484 [==============================] - ETA: 0s - loss: 3531.7720
# Epoch 2: val_loss improved from 3804.22900 to 3287.58545, saving model to my_best_model.hdf5
# 484/484 [==============================] - 147s 304ms/step - loss: 3531.7720 - val_loss: 3287.5854
# Epoch 3/100
# 484/484 [==============================] - ETA: 0s - loss: 3454.2520
# Epoch 3: val_loss improved from 3287.58545 to 3281.38696, saving model to my_best_model.hdf5
# 484/484 [==============================] - 147s 303ms/step - loss: 3454.2520 - val_loss: 3281.3870
# Epoch 4/100
# 484/484 [==============================] - ETA: 0s - loss: 3443.6885
# Epoch 4: val_loss improved from 3281.38696 to 3218.41870, saving model to my_best_model.hdf5
# 484/484 [==============================] - 146s 302ms/step - loss: 3443.6885 - val_loss: 3218.4187
# Epoch 5/100
# 484/484 [==============================] - ETA: 0s - loss: 3381.6284
# Epoch 5: val_loss did not improve from 3218.41870
# 484/484 [==============================] - 145s 299ms/step - loss: 3381.6284 - val_loss: 3260.5740
# Epoch 6/100
# 484/484 [==============================] - ETA: 0s - loss: 3329.3406
# Epoch 6: val_loss did not improve from 3218.41870
# 484/484 [==============================] - 145s 299ms/step - loss: 3329.3406 - val_loss: 3233.3730
# Epoch 7/100
# 484/484 [==============================] - ETA: 0s - loss: 3343.4866
# Epoch 7: val_loss did not improve from 3218.41870
# 484/484 [==============================] - 145s 299ms/step - loss: 3343.4866 - val_loss: 3293.4951
# Epoch 8/100
# 484/484 [==============================] - ETA: 0s - loss: 3329.8928
# Epoch 8: val_loss improved from 3218.41870 to 3192.22290, saving model to my_best_model.hdf5
# 484/484 [==============================] - 145s 299ms/step - loss: 3329.8928 - val_loss: 3192.2229
# Epoch 9/100
# 484/484 [==============================] - ETA: 0s - loss: 3320.3047
# Epoch 9: val_loss did not improve from 3192.22290
# 484/484 [==============================] - 144s 297ms/step - loss: 3320.3047 - val_loss: 3256.3257
# Epoch 10/100
# 484/484 [==============================] - ETA: 0s - loss: 3287.1982
# Epoch 10: val_loss improved from 3192.22290 to 3177.36304, saving model to my_best_model.hdf5
# 484/484 [==============================] - 144s 297ms/step - loss: 3287.1982 - val_loss: 3177.3630
# Epoch 11/100
# 484/484 [==============================] - ETA: 0s - loss: 3259.5291
# Epoch 11: val_loss improved from 3177.36304 to 3114.41772, saving model to my_best_model.hdf5
# 484/484 [==============================] - 145s 300ms/step - loss: 3259.5291 - val_loss: 3114.4177
# Epoch 12/100
# 484/484 [==============================] - ETA: 0s - loss: 3258.0503
# Epoch 12: val_loss did not improve from 3114.41772
# 484/484 [==============================] - 145s 300ms/step - loss: 3258.0503 - val_loss: 3298.8853
# Epoch 13/100
# 484/484 [==============================] - ETA: 0s - loss: 3256.3049
# Epoch 13: val_loss did not improve from 3114.41772
# 484/484 [==============================] - 144s 298ms/step - loss: 3256.3049 - val_loss: 3352.9456
# Epoch 14/100
# 484/484 [==============================] - ETA: 0s - loss: 3253.0049
# Epoch 14: val_loss did not improve from 3114.41772
# 484/484 [==============================] - 144s 297ms/step - loss: 3253.0049 - val_loss: 3186.8474
# Epoch 15/100
# 484/484 [==============================] - ETA: 0s - loss: 3250.1765
# Epoch 15: val_loss did not improve from 3114.41772
# 484/484 [==============================] - 144s 297ms/step - loss: 3250.1765 - val_loss: 3179.4001
# Epoch 16/100
# 484/484 [==============================] - ETA: 0s - loss: 3238.9421
# Epoch 16: val_loss did not improve from 3114.41772
# 484/484 [==============================] - 144s 297ms/step - loss: 3238.9421 - val_loss: 3120.5366
# Epoch 17/100
# 484/484 [==============================] - ETA: 0s - loss: 3226.1599
# Epoch 17: val_loss did not improve from 3114.41772
# 484/484 [==============================] - 144s 298ms/step - loss: 3226.1599 - val_loss: 3229.5234
# Epoch 18/100
# 484/484 [==============================] - ETA: 0s - loss: 3229.5032
# Epoch 18: val_loss did not improve from 3114.41772
# 484/484 [==============================] - 144s 298ms/step - loss: 3229.5032 - val_loss: 3120.1736
# Epoch 19/100
# 484/484 [==============================] - ETA: 0s - loss: 3214.3376
# Epoch 19: val_loss did not improve from 3114.41772
# 484/484 [==============================] - 144s 298ms/step - loss: 3214.3376 - val_loss: 3131.2568
# Epoch 20/100
# 484/484 [==============================] - ETA: 0s - loss: 3190.9290
# Epoch 20: val_loss did not improve from 3114.41772
# 484/484 [==============================] - 144s 297ms/step - loss: 3190.9290 - val_loss: 3228.5251
# Epoch 21/100
# 484/484 [==============================] - ETA: 0s - loss: 3198.1416
# Epoch 21: val_loss did not improve from 3114.41772
# 484/484 [==============================] - 144s 298ms/step - loss: 3198.1416 - val_loss: 3138.8315
# Epoch 22/100
# 484/484 [==============================] - ETA: 0s - loss: 3181.1523
# Epoch 22: val_loss did not improve from 3114.41772
# 484/484 [==============================] - 144s 298ms/step - loss: 3181.1523 - val_loss: 3137.5527
# Epoch 23/100
# 484/484 [==============================] - ETA: 0s - loss: 3183.6179
# Epoch 23: val_loss did not improve from 3114.41772
# 484/484 [==============================] - 145s 299ms/step - loss: 3183.6179 - val_loss: 3205.6567
# Epoch 24/100
# 484/484 [==============================] - ETA: 0s - loss: 3181.0964
# Epoch 24: val_loss did not improve from 3114.41772
# 484/484 [==============================] - 145s 299ms/step - loss: 3181.0964 - val_loss: 3218.3999
# Epoch 25/100
# 484/484 [==============================] - ETA: 0s - loss: 3188.2336
# Epoch 25: val_loss did not improve from 3114.41772
# 484/484 [==============================] - 144s 298ms/step - loss: 3188.2336 - val_loss: 3126.7153
# Epoch 26/100
# 484/484 [==============================] - ETA: 0s - loss: 3187.1216
# Epoch 26: val_loss did not improve from 3114.41772
# 484/484 [==============================] - 143s 296ms/step - loss: 3187.1216 - val_loss: 3291.7693
# Epoch 27/100
# 484/484 [==============================] - ETA: 0s - loss: 3164.9805
# Epoch 27: val_loss improved from 3114.41772 to 3096.58325, saving model to my_best_model.hdf5
# 484/484 [==============================] - 143s 296ms/step - loss: 3164.9805 - val_loss: 3096.5833
# Epoch 28/100
# 484/484 [==============================] - ETA: 0s - loss: 3173.6824
# Epoch 28: val_loss did not improve from 3096.58325
# 484/484 [==============================] - 143s 296ms/step - loss: 3173.6824 - val_loss: 3167.5068
# Epoch 29/100
# 484/484 [==============================] - ETA: 0s - loss: 3158.2327
# Epoch 29: val_loss did not improve from 3096.58325
# 484/484 [==============================] - 143s 296ms/step - loss: 3158.2327 - val_loss: 3121.5376
# Epoch 30/100
# 484/484 [==============================] - ETA: 0s - loss: 3177.7695
# Epoch 30: val_loss did not improve from 3096.58325
# 484/484 [==============================] - 143s 296ms/step - loss: 3177.7695 - val_loss: 3375.4817
# Epoch 31/100
# 484/484 [==============================] - ETA: 0s - loss: 3148.1262
# Epoch 31: val_loss did not improve from 3096.58325
# 484/484 [==============================] - 144s 297ms/step - loss: 3148.1262 - val_loss: 3149.5269
# Epoch 32/100
# 484/484 [==============================] - ETA: 0s - loss: 3154.1995
# Epoch 32: val_loss improved from 3096.58325 to 3081.27246, saving model to my_best_model.hdf5
# 484/484 [==============================] - 145s 299ms/step - loss: 3154.1995 - val_loss: 3081.2725
# Epoch 33/100
# 484/484 [==============================] - ETA: 0s - loss: 3155.2180
# Epoch 33: val_loss did not improve from 3081.27246
# 484/484 [==============================] - 144s 297ms/step - loss: 3155.2180 - val_loss: 3110.4058
# Epoch 34/100
# 484/484 [==============================] - ETA: 0s - loss: 3164.0278
# Epoch 34: val_loss did not improve from 3081.27246
# 484/484 [==============================] - 144s 297ms/step - loss: 3164.0278 - val_loss: 3136.5938
# Epoch 35/100
# 484/484 [==============================] - ETA: 0s - loss: 3153.0764
# Epoch 35: val_loss did not improve from 3081.27246
# 484/484 [==============================] - 144s 297ms/step - loss: 3153.0764 - val_loss: 3115.3123
# Epoch 36/100
# 484/484 [==============================] - ETA: 0s - loss: 3131.6594
# Epoch 36: val_loss improved from 3081.27246 to 3072.64990, saving model to my_best_model.hdf5
# 484/484 [==============================] - 144s 297ms/step - loss: 3131.6594 - val_loss: 3072.6499
# Epoch 37/100
# 484/484 [==============================] - ETA: 0s - loss: 3150.9780
# Epoch 37: val_loss did not improve from 3072.64990
# 484/484 [==============================] - 144s 297ms/step - loss: 3150.9780 - val_loss: 3151.7827
# Epoch 38/100
# 484/484 [==============================] - ETA: 0s - loss: 3132.7578
# Epoch 38: val_loss did not improve from 3072.64990
# 484/484 [==============================] - 144s 297ms/step - loss: 3132.7578 - val_loss: 3124.2988
# Epoch 39/100
# 484/484 [==============================] - ETA: 0s - loss: 3147.0928
# Epoch 39: val_loss did not improve from 3072.64990
# 484/484 [==============================] - 144s 297ms/step - loss: 3147.0928 - val_loss: 3093.2297
# Epoch 40/100
# 484/484 [==============================] - ETA: 0s - loss: 3127.9441
# Epoch 40: val_loss did not improve from 3072.64990
# 484/484 [==============================] - 144s 298ms/step - loss: 3127.9441 - val_loss: 3107.4797
# Epoch 41/100
# 484/484 [==============================] - ETA: 0s - loss: 3130.4377
# Epoch 41: val_loss did not improve from 3072.64990
# 484/484 [==============================] - 145s 300ms/step - loss: 3130.4377 - val_loss: 3105.3237
# Epoch 42/100
# 484/484 [==============================] - ETA: 0s - loss: 3124.6069
# Epoch 42: val_loss did not improve from 3072.64990
# 484/484 [==============================] - 143s 296ms/step - loss: 3124.6069 - val_loss: 3093.5278
# Epoch 43/100
# 484/484 [==============================] - ETA: 0s - loss: 3129.6519
# Epoch 43: val_loss did not improve from 3072.64990
# 484/484 [==============================] - 144s 298ms/step - loss: 3129.6519 - val_loss: 3303.4983
# Epoch 44/100
# 484/484 [==============================] - ETA: 0s - loss: 3116.0076
# Epoch 44: val_loss did not improve from 3072.64990
# 484/484 [==============================] - 144s 298ms/step - loss: 3116.0076 - val_loss: 3152.1924
# Epoch 45/100
# 484/484 [==============================] - ETA: 0s - loss: 3120.7251
# Epoch 45: val_loss did not improve from 3072.64990
# 484/484 [==============================] - 144s 298ms/step - loss: 3120.7251 - val_loss: 3134.6812
# Epoch 46/100
# 484/484 [==============================] - ETA: 0s - loss: 3110.4011
# Epoch 46: val_loss did not improve from 3072.64990
# 484/484 [==============================] - 143s 296ms/step - loss: 3110.4011 - val_loss: 3103.3384
# Epoch 47/100
# 484/484 [==============================] - ETA: 0s - loss: 3116.0300
# Epoch 47: val_loss did not improve from 3072.64990
# 484/484 [==============================] - 144s 298ms/step - loss: 3116.0300 - val_loss: 3095.3018
# Epoch 48/100
# 484/484 [==============================] - ETA: 0s - loss: 3109.3511
# Epoch 48: val_loss did not improve from 3072.64990
# 484/484 [==============================] - 143s 295ms/step - loss: 3109.3511 - val_loss: 3116.2258
# Epoch 49/100
# 484/484 [==============================] - ETA: 0s - loss: 3106.7510
# Epoch 49: val_loss did not improve from 3072.64990
# 484/484 [==============================] - 144s 298ms/step - loss: 3106.7510 - val_loss: 3087.1157
# Epoch 50/100
# 484/484 [==============================] - ETA: 0s - loss: 3088.0811
# Epoch 50: val_loss did not improve from 3072.64990
# 484/484 [==============================] - 145s 300ms/step - loss: 3088.0811 - val_loss: 3079.1895
# Epoch 51/100
# 484/484 [==============================] - ETA: 0s - loss: 3088.9456
# Epoch 51: val_loss did not improve from 3072.64990
# 484/484 [==============================] - 144s 297ms/step - loss: 3088.9456 - val_loss: 3150.4868
# Epoch 52/100
# 484/484 [==============================] - ETA: 0s - loss: 3098.9370
# Epoch 52: val_loss did not improve from 3072.64990
# 484/484 [==============================] - 144s 297ms/step - loss: 3098.9370 - val_loss: 3211.2961
# Epoch 53/100
# 484/484 [==============================] - ETA: 0s - loss: 3073.7129
# Epoch 53: val_loss did not improve from 3072.64990
# 484/484 [==============================] - 144s 297ms/step - loss: 3073.7129 - val_loss: 3197.0715
# Epoch 54/100
# 484/484 [==============================] - ETA: 0s - loss: 3089.0762
# Epoch 54: val_loss did not improve from 3072.64990
# 484/484 [==============================] - 143s 296ms/step - loss: 3089.0762 - val_loss: 3170.0933
# Epoch 55/100
# 484/484 [==============================] - ETA: 0s - loss: 3079.1196
# Epoch 55: val_loss did not improve from 3072.64990
# 484/484 [==============================] - 145s 300ms/step - loss: 3079.1196 - val_loss: 3085.7297
# Epoch 56/100
# 484/484 [==============================] - ETA: 0s - loss: 3088.7949
# Epoch 56: val_loss did not improve from 3072.64990
# 484/484 [==============================] - 145s 299ms/step - loss: 3088.7949 - val_loss: 3091.6973
# Epoch 57/100
# 484/484 [==============================] - ETA: 0s - loss: 3074.3625
# Epoch 57: val_loss did not improve from 3072.64990
# 484/484 [==============================] - 145s 300ms/step - loss: 3074.3625 - val_loss: 3098.4404
# Epoch 58/100
# 484/484 [==============================] - ETA: 0s - loss: 3076.6003
# Epoch 58: val_loss did not improve from 3072.64990
# 484/484 [==============================] - 145s 300ms/step - loss: 3076.6003 - val_loss: 3199.3982
# Epoch 59/100
# 484/484 [==============================] - ETA: 0s - loss: 3069.9949
# Epoch 59: val_loss did not improve from 3072.64990
# 484/484 [==============================] - 144s 297ms/step - loss: 3069.9949 - val_loss: 3092.9849
# Epoch 60/100
# 484/484 [==============================] - ETA: 0s - loss: 3057.8716
# Epoch 60: val_loss did not improve from 3072.64990
# 484/484 [==============================] - 145s 299ms/step - loss: 3057.8716 - val_loss: 3098.1714
# Epoch 61/100
# 484/484 [==============================] - ETA: 0s - loss: 3057.5115
# Epoch 61: val_loss did not improve from 3072.64990
# 484/484 [==============================] - 144s 298ms/step - loss: 3057.5115 - val_loss: 3111.5715
# Epoch 62/100
# 484/484 [==============================] - ETA: 0s - loss: 3046.2419
# Epoch 62: val_loss did not improve from 3072.64990
# 484/484 [==============================] - 144s 297ms/step - loss: 3046.2419 - val_loss: 3182.9885
# Epoch 63/100
# 484/484 [==============================] - ETA: 0s - loss: 3063.4958
# Epoch 63: val_loss did not improve from 3072.64990
# 484/484 [==============================] - 145s 300ms/step - loss: 3063.4958 - val_loss: 3121.3020
# Epoch 64/100
# 484/484 [==============================] - ETA: 0s - loss: 3049.2136
# Epoch 64: val_loss did not improve from 3072.64990
# 484/484 [==============================] - 143s 296ms/step - loss: 3049.2136 - val_loss: 3175.0134
# Epoch 65/100
# 484/484 [==============================] - ETA: 0s - loss: 3053.9436
# Epoch 65: val_loss did not improve from 3072.64990
# 484/484 [==============================] - 144s 297ms/step - loss: 3053.9436 - val_loss: 3081.3977
# Epoch 66/100
# 484/484 [==============================] - ETA: 0s - loss: 3037.7261
# Epoch 66: val_loss did not improve from 3072.64990
# 484/484 [==============================] - 143s 296ms/step - loss: 3037.7261 - val_loss: 3088.7651
# Epoch 67/100
# 484/484 [==============================] - ETA: 0s - loss: 3035.6731
# Epoch 67: val_loss did not improve from 3072.64990
# 484/484 [==============================] - 143s 296ms/step - loss: 3035.6731 - val_loss: 3134.5662
# Epoch 68/100
# 484/484 [==============================] - ETA: 0s - loss: 3044.4531
# Epoch 68: val_loss did not improve from 3072.64990
# 484/484 [==============================] - 143s 296ms/step - loss: 3044.4531 - val_loss: 3108.4917
# Epoch 69/100
# 484/484 [==============================] - ETA: 0s - loss: 3051.2812
# Epoch 69: val_loss did not improve from 3072.64990
# 484/484 [==============================] - 144s 297ms/step - loss: 3051.2812 - val_loss: 3111.6191
# Epoch 70/100
# 484/484 [==============================] - ETA: 0s - loss: 3019.3628
# Epoch 70: val_loss did not improve from 3072.64990
# 484/484 [==============================] - 143s 296ms/step - loss: 3019.3628 - val_loss: 3155.2305
# Epoch 71/100
# 484/484 [==============================] - ETA: 0s - loss: 3018.6389
# Epoch 71: val_loss did not improve from 3072.64990
# 484/484 [==============================] - 144s 297ms/step - loss: 3018.6389 - val_loss: 3119.5881
# Epoch 72/100
# 484/484 [==============================] - ETA: 0s - loss: 3012.1616
# Epoch 72: val_loss did not improve from 3072.64990
# 484/484 [==============================] - 144s 297ms/step - loss: 3012.1616 - val_loss: 3107.0720
# Epoch 73/100
# 484/484 [==============================] - ETA: 0s - loss: 3018.1279
# Epoch 73: val_loss did not improve from 3072.64990
# 484/484 [==============================] - 144s 297ms/step - loss: 3018.1279 - val_loss: 3121.0002
# Epoch 74/100
# 484/484 [==============================] - ETA: 0s - loss: 3009.3542
# Epoch 74: val_loss did not improve from 3072.64990
# 484/484 [==============================] - 143s 295ms/step - loss: 3009.3542 - val_loss: 3153.3357
# Epoch 75/100
# 484/484 [==============================] - ETA: 0s - loss: 3007.7832
# Epoch 75: val_loss did not improve from 3072.64990
# 484/484 [==============================] - 144s 297ms/step - loss: 3007.7832 - val_loss: 3114.0571
# Epoch 76/100
# 484/484 [==============================] - ETA: 0s - loss: 2998.0254
# Epoch 76: val_loss did not improve from 3072.64990
# 484/484 [==============================] - 143s 295ms/step - loss: 2998.0254 - val_loss: 3138.1865
# Epoch 77/100
# 484/484 [==============================] - ETA: 0s - loss: 2998.3040
# Epoch 77: val_loss did not improve from 3072.64990
# 484/484 [==============================] - 143s 296ms/step - loss: 2998.3040 - val_loss: 3210.9670
# Epoch 78/100
# 484/484 [==============================] - ETA: 0s - loss: 2993.9473
# Epoch 78: val_loss did not improve from 3072.64990
# 484/484 [==============================] - 153s 317ms/step - loss: 2993.9473 - val_loss: 3150.3584
# Epoch 79/100
# 484/484 [==============================] - ETA: 0s - loss: 2994.3298
# Epoch 79: val_loss did not improve from 3072.64990
# 484/484 [==============================] - 145s 299ms/step - loss: 2994.3298 - val_loss: 3206.3135
# Epoch 80/100
# 484/484 [==============================] - ETA: 0s - loss: 2988.3018
# Epoch 80: val_loss did not improve from 3072.64990
# 484/484 [==============================] - 144s 297ms/step - loss: 2988.3018 - val_loss: 3120.2375
# Epoch 81/100
# 484/484 [==============================] - ETA: 0s - loss: 2967.3860
# Epoch 81: val_loss did not improve from 3072.64990
# 484/484 [==============================] - 144s 297ms/step - loss: 2967.3860 - val_loss: 3161.4138
# Epoch 82/100
# 484/484 [==============================] - ETA: 0s - loss: 2984.2822
# Epoch 82: val_loss did not improve from 3072.64990
# 484/484 [==============================] - 144s 298ms/step - loss: 2984.2822 - val_loss: 3149.3076
# Epoch 83/100
# 484/484 [==============================] - ETA: 0s - loss: 2978.6501
# Epoch 83: val_loss did not improve from 3072.64990
# 484/484 [==============================] - 144s 297ms/step - loss: 2978.6501 - val_loss: 3151.5798
# Epoch 84/100
# 484/484 [==============================] - ETA: 0s - loss: 2970.9143
# Epoch 84: val_loss did not improve from 3072.64990
# 484/484 [==============================] - 144s 298ms/step - loss: 2970.9143 - val_loss: 3122.1638
# Epoch 85/100
# 484/484 [==============================] - ETA: 0s - loss: 2959.3291
# Epoch 85: val_loss did not improve from 3072.64990
# 484/484 [==============================] - 144s 297ms/step - loss: 2959.3291 - val_loss: 3146.7070
# Epoch 86/100
# 484/484 [==============================] - ETA: 0s - loss: 2970.9114
# Epoch 86: val_loss did not improve from 3072.64990
# 484/484 [==============================] - 144s 297ms/step - loss: 2970.9114 - val_loss: 3262.4231
# Epoch 87/100
# 484/484 [==============================] - ETA: 0s - loss: 2949.7227
# Epoch 87: val_loss did not improve from 3072.64990
# 484/484 [==============================] - 143s 297ms/step - loss: 2949.7227 - val_loss: 3128.3245
# Epoch 88/100
# 484/484 [==============================] - ETA: 0s - loss: 2942.4194
# Epoch 88: val_loss did not improve from 3072.64990
# 484/484 [==============================] - 143s 296ms/step - loss: 2942.4194 - val_loss: 3153.9470
# Epoch 89/100
# 484/484 [==============================] - ETA: 0s - loss: 2959.2527
# Epoch 89: val_loss did not improve from 3072.64990
# 484/484 [==============================] - 143s 296ms/step - loss: 2959.2527 - val_loss: 3211.7817
# Epoch 90/100
# 484/484 [==============================] - ETA: 0s - loss: 2947.1858
# Epoch 90: val_loss did not improve from 3072.64990
# 484/484 [==============================] - 145s 300ms/step - loss: 2947.1858 - val_loss: 3149.9404
# Epoch 91/100
# 484/484 [==============================] - ETA: 0s - loss: 2934.9705
# Epoch 91: val_loss did not improve from 3072.64990
# 484/484 [==============================] - 145s 300ms/step - loss: 2934.9705 - val_loss: 3145.5999
# Epoch 92/100
# 484/484 [==============================] - ETA: 0s - loss: 2932.8081
# Epoch 92: val_loss did not improve from 3072.64990
# 484/484 [==============================] - 145s 300ms/step - loss: 2932.8081 - val_loss: 3134.0847
# Epoch 93/100
# 484/484 [==============================] - ETA: 0s - loss: 2919.7495
# Epoch 93: val_loss did not improve from 3072.64990
# 484/484 [==============================] - 150s 309ms/step - loss: 2919.7495 - val_loss: 3162.1938
# Epoch 94/100
# 484/484 [==============================] - ETA: 0s - loss: 2934.5920
# Epoch 94: val_loss did not improve from 3072.64990
# 484/484 [==============================] - 148s 305ms/step - loss: 2934.5920 - val_loss: 3170.5518
# Epoch 95/100
# 484/484 [==============================] - ETA: 0s - loss: 2930.7319
# Epoch 95: val_loss did not improve from 3072.64990
# 484/484 [==============================] - 147s 303ms/step - loss: 2930.7319 - val_loss: 3194.3928
# Epoch 96/100
# 484/484 [==============================] - ETA: 0s - loss: 2917.9307
# Epoch 96: val_loss did not improve from 3072.64990
# 484/484 [==============================] - 149s 308ms/step - loss: 2917.9307 - val_loss: 3130.2590
# Epoch 97/100
# 484/484 [==============================] - ETA: 0s - loss: 2904.5295
# Epoch 97: val_loss did not improve from 3072.64990
# 484/484 [==============================] - 145s 299ms/step - loss: 2904.5295 - val_loss: 3166.1938
# Epoch 98/100
# 484/484 [==============================] - ETA: 0s - loss: 2907.8374
# Epoch 98: val_loss did not improve from 3072.64990
# 484/484 [==============================] - 145s 299ms/step - loss: 2907.8374 - val_loss: 3167.0266
# Epoch 99/100
# 484/484 [==============================] - ETA: 0s - loss: 2901.4714
# Epoch 99: val_loss did not improve from 3072.64990
# 484/484 [==============================] - 145s 300ms/step - loss: 2901.4714 - val_loss: 3185.4346
# Epoch 100/100
# 484/484 [==============================] - ETA: 0s - loss: 2899.1946
# Epoch 100: val_loss did not improve from 3072.64990
# 484/484 [==============================] - 144s 298ms/step - loss: 2899.1946 - val_loss: 3167.7544

# %% [markdown]
# * Plot the training process
# * if the best model occurs in the middle of epochs, it is overfitting, otherwise, more traning epochs are needed.

# %%
plt.figure(figsize=(8, 8))
plt.title("Optimization curve(Epochs vs Log-loss)")
plt.plot(history.history["loss"], label="loss")
plt.plot(history.history["val_loss"], label="val_loss")
plt.plot(np.argmin(history.history["val_loss"]), np.min(history.history["val_loss"]), marker="x", color="r", label="best model")
plt.xlabel("Epochs")
plt.ylabel("log_loss")
plt.legend()

# %% [markdown]
# # Step 5: Load the best model and use it to predict RGB images, compared with actral RGB images (ground truth)

# %%
#Load the best model version
model = load_model(filepath)
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_3_input (InputLayer)  [(None, 256, 256, 3)]    0
#
#  conv2d_3 (Conv2D)           (None, 256, 256, 32)      896
#
#  max_pooling2d_3 (MaxPooling  (None, 128, 128, 32)     0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 128, 128, 64)      18496
#
#  max_pooling2d_4 (MaxPooling  (None, 64, 64, 64)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 64, 64, 128)       73856
#
#  max_pooling2d_5 (MaxPooling  (None, 32, 32, 128)      0
#  2D)
#
#  sequential_3 (Sequential)   (None, 256, 256, 3)       166467
#
# =================================================================
# Total params: 259,715
# Trainable params: 259,715
# Non-trainable params: 0
# _________________________________________________________________

# %%
RGB_predicted = model.predict(thermal_test_)
print('Model MSE on test data = ', loss_fn(gt_test_, RGB_predicted).numpy())
# Out:
# Model MSE on test data =  3072.6494

# %%
plt.imshow(thermal_test_[27])
#print(type(thermal_test_[5]))

# %%
plt.imshow(RGB_predicted[27]/255)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
plt.imshow(gt_test_[27])

# %%
def plotImages(images_arr):
  fig,axes = plt.subplots(1,10,figsize=(20,20))
  axes=axes.flatten()
  for img,ax in zip(images_arr,axes):
    img=img.astype(np.uint)
    ax.imshow(img)
    ax.axis('off')
  plt.tight_layout()
  plt.show()

# %%
plotImages(RGB_predicted[10:20])
plotImages(thermal_test_[10:20])
plotImages(gt_test_[10:20])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
